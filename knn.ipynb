# %%
from utils.loadData import load_data, TRAIN_DATA_POINTS, TEST_DATA_POINTS, N_CLASSES
from utils.processing import generate_class_matrix, generate_test_class_matrix

train_data = load_data("data/ae.train", num_data_points=TRAIN_DATA_POINTS)
test_data = load_data("data/ae.test", num_data_points=TEST_DATA_POINTS)

train_class_matrix = generate_class_matrix(TRAIN_DATA_POINTS, N_CLASSES)
test_class_matrix = generate_test_class_matrix(TEST_DATA_POINTS, N_CLASSES)
# Out:
# Successfully created a NumPy array with shape: (270, 29, 12)
# Successfully created a NumPy array with shape: (370, 29, 12)

# %% [markdown]
# The following block of code is run to perform a hyperparameter search on the number of nearest neighbors.

# %%
from knn.knn_pipeline import knn_hyperparameter_search

k_to_search = range(1, 11)
path = "search_results.txt"

# leave-one-out cross validation
knn_hyperparameter_search(
    data=train_data, 
    labels=train_class_matrix, 
    k_to_search=k_to_search, 
    k_folds=TRAIN_DATA_POINTS, 
    results_location=path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from knn_pipeline import knn_hyperparameter_search
#       3 k_to_search = range(1, 11)
#       4 path = "search_results.txt"
#
# File ~/ML/AML_Group13/knn/knn_pipeline.py:3
#       1 import numpy as np
#       2 from typing import List
# ----> 3 from loadData import load_data, TRAIN_DATA_POINTS, TEST_DATA_POINTS, N_CLASSES
#       4 from processing import generate_class_matrix
#       5 from DynamicTimeWarping import DTW
#
# ModuleNotFoundError: No module named 'loadData'

# %% [markdown]
# The results of the hyperparameter search for 1 through 10 nearest neighbors are shown by the function in the next block.
# The search is done for two different local distance measures in the Dynamic Time Warping (DTW) procedure. The local distance measures are the absolute distance and the squared distance.

# %%
from utils.visualizeData import show_search_results

show_search_results()

# %%
from knn.knn_pipeline import knn_accuracy

k_nn = 3
accuracy = knn_accuracy(k_nn, test_data, test_class_matrix, train_data, train_class_matrix)
accuracy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from knn.knn_pipeline import knn_accuracy
#       3 k_nn = 3
#       4 accuracy = knn_accuracy(k_nn, test_data, test_class_matrix, train_data, train_class_matrix)
#
# File ~/ML/AML_Group13/knn/knn_pipeline.py:5
#       3 from utils.loadData import load_data, TRAIN_DATA_POINTS, TEST_DATA_POINTS, N_CLASSES
#       4 from utils.processing import generate_class_matrix
# ----> 5 from DynamicTimeWarping import DTW
#       8 def get_distances(data_point: np.ndarray, training_data: np.ndarray) -> List[float]:
#       9     """
#      10     Collects the Dynamic Time Warping (DTW) distances from a data point to all
#      11     other data points in the training data.
#    (...)     20         in training_data
#      21     """
#
# ModuleNotFoundError: No module named 'DynamicTimeWarping'

# %%
mismatch = 100 - accuracy
mismatch
